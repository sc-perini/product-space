# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:/Users/sperini.NOTEBOOK44/Documents/Git/product-space/data/processed/datos_expo_wide.csv', index_col=None)
# Out:
# C:\Programas\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#             ReporterISO3             ProductCode            ReporterName  \
# 0                    ABW                     101                   Aruba
# 1                    ABW                     103                   Aruba
# 2                    ABW                     104                   Aruba
# 3                    ABW                     105                   Aruba
# 4                    ABW                     106                   Aruba
# ...                  ...                     ...                     ...
# 181033               YEM               YEM_Total               YEM_Total
# 181034               ZAF               ZAF_Total               ZAF_Total
# 181035               ZMB               ZMB_Total               ZMB_Total
# 181036               ZWE               ZWE_Total               ZWE_Total
# 181037  Todos los paises  Todos los paises_Total  Todos los paises_Total
#
#                 1997          1998          1999          2007          2008  \
# ...

# %%
# si quisiera seleccionar solo columnas numéricas 
# numeric_inputs = df.select_dtypes(include=np.number)

# %%
# pruebo con un ejemplo para luego escalarlo a todos
df.loc[df['ReporterISO3']=='ABW','prom_1719']
# Out:
# 0             6.68
# 1              NaN
# 2              NaN
# 3            49.68
# 4             9.10
#             ...
# 785         102.07
# 786            NaN
# 787           9.18
# 788        4484.50
# 180844    82523.51
# Name: prom_1719, Length: 790, dtype: float64

# %%
df.loc[df['ReporterISO3']=='ABW','prom_1719'] / 82523.51
# Out:
# 0         0.000081
# 1              NaN
# 2              NaN
# 3         0.000602
# 4         0.000110
#             ...
# 785       0.001237
# 786            NaN
# 787       0.000111
# 788       0.054342
# 180844    1.000000
# Name: prom_1719, Length: 790, dtype: float64

# %%
pd.to_numeric(df.loc[df['ProductCode']==('ABW'+'_Total'),'prom_1719'], errors='coerce')
# Out:
# 180844    82523.51
# Name: prom_1719, dtype: float64

# %%
df.loc[df['ProductCode']==('ABW'+'_Total'),'prom_1719'].values
# Out:
# array([82523.51])

# %%
df
# Out:
#             ReporterISO3             ProductCode            ReporterName  \
# 0                    ABW                     101                   Aruba
# 1                    ABW                     103                   Aruba
# 2                    ABW                     104                   Aruba
# 3                    ABW                     105                   Aruba
# 4                    ABW                     106                   Aruba
# ...                  ...                     ...                     ...
# 181033               YEM               YEM_Total               YEM_Total
# 181034               ZAF               ZAF_Total               ZAF_Total
# 181035               ZMB               ZMB_Total               ZMB_Total
# 181036               ZWE               ZWE_Total               ZWE_Total
# 181037  Todos los paises  Todos los paises_Total  Todos los paises_Total
#
#                 1997          1998          1999          2007          2008  \
# ...

# %%
(df.loc[df['ReporterISO3']=='ABW','prom_1719']) / (df.loc[df['ProductCode']==('ABW'+'_Total'),'prom_1719'].values)
# Out:
# 0         0.000081
# 1              NaN
# 2              NaN
# 3         0.000602
# 4         0.000110
#             ...
# 785       0.001237
# 786            NaN
# 787       0.000111
# 788       0.054342
# 180844    1.000000
# Name: prom_1719, Length: 790, dtype: float64

# %%
df.prom_1719
# Out:
# 0         6.680000e+00
# 1                  NaN
# 2                  NaN
# 3         4.968000e+01
# 4         9.100000e+00
#               ...
# 181033    1.019419e+04
# 181034    8.921997e+07
# 181035    8.001964e+06
# 181036    3.942767e+06
# 181037    2.015527e+10
# Name: prom_1719, Length: 181038, dtype: float64

# %%
df.loc[df['ProductCode']==(df.ReporterISO3+'_Total'),'prom_1719'].values
# Out:
# array([8.25235100e+04, 8.75520180e+05, 3.89814312e+07, 2.62953990e+06,
#        1.24162010e+05, 0.00000000e+00, 2.32910770e+08, 6.31179587e+07,
#        2.23224544e+06, 2.82741000e+03, 2.49793303e+08, 1.69548046e+08,
#        1.81600916e+07, 1.65975310e+05, 4.48291427e+08, 8.09316820e+05,
#        3.12079276e+06, 0.00000000e+00, 3.29632290e+07, 1.20598309e+07,
#        5.02013150e+05, 6.71806143e+06, 3.19886499e+07, 0.00000000e+00,
#        2.10043750e+05, 3.09573500e+04, 8.62246374e+06, 2.27678737e+08,
#        3.22627430e+05, 6.31402325e+06, 0.00000000e+00, 5.77020175e+06,
#        1.31989250e+05, 4.03613465e+08, 3.07820900e+08, 7.13554200e+07,
#        2.41872459e+09, 1.23454018e+07, 6.52731078e+06, 8.44783807e+06,
#        0.00000000e+00, 3.97023671e+07, 4.73196800e+04, 6.30140600e+04,
#        1.13475987e+07, 0.00000000e+00, 1.59071667e+06, 1.94742912e+08,
#        1.50247609e+09, 0.00000000e+00, 0.00000000e+00, 1.06651151e+08,
# ...

# %%
df.loc[df['ProductCode']==(df.ReporterISO3+'_Total')]
# Out:
#             ReporterISO3             ProductCode            ReporterName  \
# 180844               ABW               ABW_Total               ABW_Total
# 180845               AFG               AFG_Total               AFG_Total
# 180846               AGO               AGO_Total               AGO_Total
# 180847               ALB               ALB_Total               ALB_Total
# 180848               AND               AND_Total               AND_Total
# ...                  ...                     ...                     ...
# 181033               YEM               YEM_Total               YEM_Total
# 181034               ZAF               ZAF_Total               ZAF_Total
# 181035               ZMB               ZMB_Total               ZMB_Total
# 181036               ZWE               ZWE_Total               ZWE_Total
# 181037  Todos los paises  Todos los paises_Total  Todos los paises_Total
#
#                 1997          1998          1999          2007          2008  \
# ...

# %%
df.loc[df['ProductCode']==(df.ReporterISO3+'_Total'),'prom_1719']
# Out:
# 180844    8.252351e+04
# 180845    8.755202e+05
# 180846    3.898143e+07
# 180847    2.629540e+06
# 180848    1.241620e+05
#               ...
# 181033    1.019419e+04
# 181034    8.921997e+07
# 181035    8.001964e+06
# 181036    3.942767e+06
# 181037    2.015527e+10
# Name: prom_1719, Length: 194, dtype: float64

# %%
df2 = pd.read_csv('C:/Users/sperini.NOTEBOOK44/Documents/Git/product-space/data/processed/datos_expo_long.csv', index_col=None)
df2
# Out:
#         Nomenclature ReporterISO3  ProductCode ReporterName PartnerISO3  \
# 0                 H1          ALB          101      Albania         WLD
# 1                 H1          ALB          105      Albania         WLD
# 2                 H1          ALB          106      Albania         WLD
# 3                 H1          ALB          206      Albania         WLD
# 4                 H1          ALB          207      Albania         WLD
# ...              ...          ...          ...          ...         ...
# 1018158           H1          ZWE         9618     Zimbabwe         WLD
# 1018159           H1          ZWE         9701     Zimbabwe         WLD
# 1018160           H1          ZWE         9703     Zimbabwe         WLD
# 1018161           H1          ZWE         9705     Zimbabwe         WLD
# 1018162           H1          ZWE         9999     Zimbabwe         WLD
#
#         PartnerName  Year TradeFlowName  TradeFlowCode  TradeValue in 1000 USD
# ...

# %% [markdown]
# Calculo de VCR obtenido de [QuantEconNotes](https://notes.quantecon.org/submission/5b32e9b0b9eab00015b89f7d)

# %%
data = df2[["ReporterISO3", "ProductCode", 'ReporterName', 'Year', 'TradeValue in 1000 USD']]
data
# Out:
#         ReporterISO3  ProductCode ReporterName  Year  TradeValue in 1000 USD
# 0                ALB          101      Albania  1997                  14.538
# 1                ALB          105      Albania  1997                  10.612
# 2                ALB          106      Albania  1997                  34.767
# 3                ALB          206      Albania  1997                  18.225
# 4                ALB          207      Albania  1997                 105.227
# ...              ...          ...          ...   ...                     ...
# 1018158          ZWE         9618     Zimbabwe  2019                   0.456
# 1018159          ZWE         9701     Zimbabwe  2019                  32.100
# 1018160          ZWE         9703     Zimbabwe  2019                2172.791
# 1018161          ZWE         9705     Zimbabwe  2019                8252.694
# 1018162          ZWE         9999     Zimbabwe  2019                1450.204
#
# [1018163 rows x 5 columns]

# %%
# uso la función transform para que me devuelva un objeto del mismo tipo que el dataframe original
data['X_pais'] = data[["Year", "ReporterISO3", 'TradeValue in 1000 USD']].groupby(by=["Year", "ReporterISO3"]).transform(np.sum)
data["X_prod"] = data[["Year", "ProductCode", 'TradeValue in 1000 USD']].groupby(by=["Year", "ProductCode"]).transform(np.sum)
data["X_world"] = data[["Year", 'TradeValue in 1000 USD']].groupby(by=["Year"]).transform(np.sum)
# Out:
# <ipython-input-182-735d38501ac8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['X_pais'] = data[["Year", "ReporterISO3", 'TradeValue in 1000 USD']].groupby(by=["Year", "ReporterISO3"]).transform(np.sum)
# <ipython-input-182-735d38501ac8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["X_prod"] = data[["Year", "ProductCode", 'TradeValue in 1000 USD']].groupby(by=["Year", "ProductCode"]).transform(np.sum)
# <ipython-input-182-735d38501ac8>:4: SettingWithCopyWarning:
# ...

# %%
data
# Out:
#         ReporterISO3  ProductCode ReporterName  Year  TradeValue in 1000 USD  \
# 0                ALB          101      Albania  1997                  14.538
# 1                ALB          105      Albania  1997                  10.612
# 2                ALB          106      Albania  1997                  34.767
# 3                ALB          206      Albania  1997                  18.225
# 4                ALB          207      Albania  1997                 105.227
# ...              ...          ...          ...   ...                     ...
# 1018158          ZWE         9618     Zimbabwe  2019                   0.456
# 1018159          ZWE         9701     Zimbabwe  2019                  32.100
# 1018160          ZWE         9703     Zimbabwe  2019                2172.791
# 1018161          ZWE         9705     Zimbabwe  2019                8252.694
# 1018162          ZWE         9999     Zimbabwe  2019                1450.204
#
# ...

# %%
df = pd.read_csv('C:/Users/sperini.NOTEBOOK44/Documents/Git/product-space/data/processed/datos_expo_wide.csv', index_col=None)
# Out:
# C:\Programas\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#             ReporterISO3             ProductCode            ReporterName  \
# 0                    ABW                     101                   Aruba
# 1                    ABW                     103                   Aruba
# 2                    ABW                     104                   Aruba
# 3                    ABW                     105                   Aruba
# 4                    ABW                     106                   Aruba
# ...                  ...                     ...                     ...
# 181033               YEM               YEM_Total               YEM_Total
# 181034               ZAF               ZAF_Total               ZAF_Total
# 181035               ZMB               ZMB_Total               ZMB_Total
# 181036               ZWE               ZWE_Total               ZWE_Total
# 181037  Todos los paises  Todos los paises_Total  Todos los paises_Total
#
#                 1997          1998          1999          2007          2008  \
# ...

# %%
# si quisiera seleccionar solo columnas numéricas 
# numeric_inputs = df.select_dtypes(include=np.number)
df['ProductCode'].nunique()
# Out:
# 2678

# %%
df.loc[df['ProductCode']==(df.ReporterISO3+'_Total')]
# Out:
#             ReporterISO3             ProductCode            ReporterName  \
# 180844               ABW               ABW_Total               ABW_Total
# 180845               AFG               AFG_Total               AFG_Total
# 180846               AGO               AGO_Total               AGO_Total
# 180847               ALB               ALB_Total               ALB_Total
# 180848               AND               AND_Total               AND_Total
# ...                  ...                     ...                     ...
# 181033               YEM               YEM_Total               YEM_Total
# 181034               ZAF               ZAF_Total               ZAF_Total
# 181035               ZMB               ZMB_Total               ZMB_Total
# 181036               ZWE               ZWE_Total               ZWE_Total
# 181037  Todos los paises  Todos los paises_Total  Todos los paises_Total
#
#                 1997          1998          1999          2007          2008  \
# ...

# %%
df.loc[(df['ProductCode']!=(df.ReporterISO3+'_Total'))]
# Out:
#             ReporterISO3 ProductCode ReporterName          1997          1998  \
# 0                    ABW         101        Aruba           NaN           NaN
# 1                    ABW         103        Aruba           NaN           NaN
# 2                    ABW         104        Aruba           NaN           NaN
# 3                    ABW         105        Aruba           NaN           NaN
# 4                    ABW         106        Aruba           NaN           NaN
# ...                  ...         ...          ...           ...           ...
# 180839  Todos los paises        9703          TOT  4.995609e+05  5.288797e+05
# 180840  Todos los paises        9704          TOT  2.039868e+05  1.748930e+05
# 180841  Todos los paises        9705          TOT  2.854066e+05  3.425063e+05
# 180842  Todos los paises        9706          TOT  1.445352e+06  1.337021e+06
# 180843  Todos los paises        9999          TOT  1.199337e+08  1.107682e+08
#
# ...

# %%
df.loc[(df['ProductCode']!=(df.ReporterISO3+'_Total'))]['ProductCode'].nunique()
# Out:
# 2484

# %%
df.loc[(df['ProductCode']!=(df.ReporterISO3+'_Total'))]['ProductCode'].to_numpy()
# Out:
# array([101, 103, 104, ..., '9705', '9706', '9999'], dtype=object)

# %%
# países para los que no hay datos 9799
df.loc[(df['ProductCode']==(df.ReporterISO3+'_Total')) & (df['prom_9799']==0)].ReporterISO3.to_numpy() 
# 67 paises
# Out:
# array(['ABW', 'AFG', 'AGO', 'BDI', 'BFA', 'BGD', 'BHR', 'BIH', 'BMU',
#        'BRB', 'BRN', 'BWA', 'CIV', 'CMR', 'COG', 'COK', 'COM', 'DJI',
#        'DOM', 'EGY', 'ETH', 'EUN', 'FJI', 'FSM', 'GHA', 'GRD', 'KGZ',
#        'KHM', 'KIR', 'KWT', 'LAO', 'LBY', 'LCA', 'LSO', 'MAR', 'MDA',
#        'MMR', 'MNT', 'MRT', 'MYT', 'NAM', 'NCL', 'OAS', 'OMN', 'PAK',
#        'PHL', 'PLW', 'PSE', 'QAT', 'RWA', 'SER', 'SLB', 'SLE', 'SUD',
#        'SUR', 'SWZ', 'SYR', 'TMP', 'TON', 'TUN', 'UKR', 'UZB', 'VNM',
#        'VUT', 'WSM', 'YEM', 'ZWE'], dtype=object)

# %%
# países para los que no hay datos 0709
df.loc[(df['ProductCode']==(df.ReporterISO3+'_Total')) & (df['prom_0709']==0)].ReporterISO3.to_numpy() 
# 13 paises
# Out:
# array(['BLX', 'BMU', 'CUB', 'HTI', 'IRN', 'LAO', 'MMR', 'PLW', 'SLE',
#        'SUD', 'TKM', 'TMP', 'UZB'], dtype=object)

# %%
# países para los que no hay datos 1719
df.loc[(df['ProductCode']==(df.ReporterISO3+'_Total')) & (df['prom_1719']==0)].ReporterISO3.to_numpy() 
# 27 paises
# Out:
# array(['ANT', 'BGD', 'BLX', 'BTN', 'COK', 'CUB', 'DJI', 'DMA', 'FRO',
#        'FSM', 'GAB', 'GIN', 'GRD', 'HTI', 'KIR', 'MSR', 'MYT', 'NCL',
#        'PYF', 'SDN', 'SYR', 'TCA', 'TKM', 'TON', 'TTO', 'VEN', 'VUT'],
#       dtype=object)

# %%
# armo nuevo data frame descartando la filas de todos los países y el total por país porque lo voy a calcular en columnas ahora
df_ = df.loc[df['ProductCode']!=(df.ReporterISO3+'_Total')] 
df_ = df_.loc[df_['ReporterISO3']!=('Todos los paises')]
df_
# Out:
#        ReporterISO3 ProductCode ReporterName  1997  1998  1999       2007  \
# 0               ABW         101        Aruba   NaN   NaN   NaN      1.809
# 1               ABW         103        Aruba   NaN   NaN   NaN        NaN
# 2               ABW         104        Aruba   NaN   NaN   NaN      0.642
# 3               ABW         105        Aruba   NaN   NaN   NaN      6.849
# 4               ABW         106        Aruba   NaN   NaN   NaN      5.834
# ...             ...         ...          ...   ...   ...   ...        ...
# 179597          ZWE        9702     Zimbabwe   NaN   NaN   NaN        NaN
# 179598          ZWE        9703     Zimbabwe   NaN   NaN   NaN   4844.384
# 179599          ZWE        9704     Zimbabwe   NaN   NaN   NaN      2.376
# 179600          ZWE        9705     Zimbabwe   NaN   NaN   NaN  30099.052
# 179601          ZWE        9999     Zimbabwe   NaN   NaN   NaN   9485.615
#
#              2008       2009      2017      2018      2019  prom_1719  \
# ...

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179602 entries, 0 to 179601
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ReporterISO3  179602 non-null  object
#  1   ProductCode   179602 non-null  object
#  2   ReporterName  179602 non-null  object
#  3   1997          72901 non-null   float64
#  4   1998          84720 non-null   float64
#  5   1999          96132 non-null   float64
#  6   2007          128697 non-null  float64
#  7   2008          129378 non-null  float64
#  8   2009          132133 non-null  float64
#  9   2017          133220 non-null  float64
#  10  2018          127526 non-null  float64
#  11  2019          113456 non-null  float64
#  12  prom_1719     147283 non-null  float64
#  13  prom_0709     152110 non-null  float64
#  14  prom_9799     108184 non-null  float64
# dtypes: float64(12), object(3)
# memory usage: 21.9+ MB

# %%
df_.ProductCode.nunique()
# Out:
# 2484

# %%
df_
# Out:
#        ReporterISO3 ProductCode ReporterName  1997  1998  1999       2007  \
# 0               ABW         101        Aruba   NaN   NaN   NaN      1.809
# 1               ABW         103        Aruba   NaN   NaN   NaN        NaN
# 2               ABW         104        Aruba   NaN   NaN   NaN      0.642
# 3               ABW         105        Aruba   NaN   NaN   NaN      6.849
# 4               ABW         106        Aruba   NaN   NaN   NaN      5.834
# ...             ...         ...          ...   ...   ...   ...        ...
# 179597          ZWE        9702     Zimbabwe   NaN   NaN   NaN        NaN
# 179598          ZWE        9703     Zimbabwe   NaN   NaN   NaN   4844.384
# 179599          ZWE        9704     Zimbabwe   NaN   NaN   NaN      2.376
# 179600          ZWE        9705     Zimbabwe   NaN   NaN   NaN  30099.052
# 179601          ZWE        9999     Zimbabwe   NaN   NaN   NaN   9485.615
#
#              2008       2009      2017      2018      2019  prom_1719  \
# ...
