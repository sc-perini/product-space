# %%
import tabula as tb
import pandas as pd

# %%
box = [1.5, 22,3.8,26.741]
fc = 28.28
         
for i in range(0, len(box)):
    box[i] *= fc

# %%
pages = [26,27]
file = '../references/Medicion_de_la_Bioeconomia_-_Cuantificacion_del_Caso_Argentino.pdf'

# %%
tabla = tb.read_pdf(file, pages='27')
# Out:
# Got stderr: may. 24, 2021 2:07:52 P. M. org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# ADVERTENCIA: ICC profile is Perceptual, ignoring, treating as Display class
# may. 24, 2021 2:07:54 P. M. org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# ADVERTENCIA: ICC profile is Perceptual, ignoring, treating as Display class

# %%
tabla[9]
# Out:
#    ANEXO 2:  Actividades consideradas para estimar la bioeconomía    17113  \
# 0                                                 NaN              17114.0
# 1   Participación de la bioeconomía en el valor ag...              17120.0
# 2                                            Año 2012              17210.0
# 3                                                 NaN                  NaN
# 4                 CIIU Rev3 Concepto  Participación %              17220.0
# 5   Letra A Agricultura, ganadería, caza y silvicu...              17230.0
# 6                                   Letra B Pesca 100              17290.0
# 7                 Letra D Industria Manufacturera Bio              17301.0
# 8                                                 NaN              17302.0
# 9   15111 Matanza de ganado, producción, procesami...              17309.0
# 10  vaca, oveja,  cerdo, liebre y otros animales, ...              18101.0
# ...
