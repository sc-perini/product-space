# %%
import pandas as pd
import world_trade_data as wits

# %%
wits.get_countries()
# Out:
#                                     name notes countrycode  isreporter  \
# iso3Code
# AFG                          Afghanistan               004       False
# ALB                              Albania               008       False
# DZA                              Algeria               012       False
# ASM                       American Samoa               016        True
# AND                              Andorra               020       False
# ...                                  ...   ...         ...         ...
# YEM                                Yemen               887       False
# YDR                     Yemen Democratic               720        True
# YUG       Yugoslavia,FR(Serbia/Montenegr               890        True
# ZMB                               Zambia               894       False
# ZWE                             Zimbabwe               716       False
#
#           ispartner isgroup grouptype
# iso3Code
# AFG           False      No       N/A
# ...

# %%
wits.get_products()
# Out:
#                 isgroup nomenclaturecode             grouptype  \
# productcode
# 999999              N/A              N/A                   N/A
# 01-05_Animal        Yes               H0                Sector
# 06-15_Vegetable     Yes               H0                Sector
# 16-24_FoodProd      Yes               H0                Sector
# 25-26_Minerals      Yes               H0                Sector
# 27-27_Fuels         Yes               H0                Sector
# 28-38_Chemicals     Yes               H0                Sector
# 39-40_PlastiRub     Yes               H0                Sector
# 41-43_HidesSkin     Yes               H0                Sector
# 44-49_Wood          Yes               H0                Sector
# 50-63_TextCloth     Yes               H0                Sector
# 64-67_Footwear      Yes               H0                Sector
# 68-71_StoneGlas     Yes               H0                Sector
# 72-83_Metals        Yes               H0                Sector
# ...

# %%
wits.get_indicators()
# Out:
#                     ispartnerequired SDMX_partnervalue isproductrequired  \
# indicatorcode
# CNTRY-GRWTH                      yes                                 yes
# HH-MKT-CNCNTRTN-NDX               no               999                no
# MPRT-PRDCT-SHR                   yes                                 yes
# MPRT-PRTNR-SHR                   yes                                  no
# MPRT-SHR-TTL-PRDCT               yes                                 yes
# MPRT-TRD-VL                      yes                                 yes
# NDX-XPRT-MKT-PNRTTN               no               999                no
# NMBR-MPRT-HS6-PRDCT              yes                                  no
# NMBR-MPRT-PRTNR                   no               999                no
# NMBR-PRDCT-MPRTD                  no               999                no
# NMBR-PRDCT-XPRTD                  no               999                no
# NMBR-XPRT-HS6-PRDCT              yes                                  no
# ...

# %%
import requests
url='https://comtrade.un.org/api/get?max=100&type=C&freq=A&px=HS&ps=2019&r=all&p=World&rg=all&cc=1206'
un_data=requests.get(url)
print(un_data.content)
# Out:
# b'{"validation":{"status":{"name":"Invalid parameter","value":5004,"category":0,"description":"the selected query does not accept the passed option.","helpUrl":"For more reference visit http://comtrade.un.org/data/dev/portal/"},"message":"Invalid argument format: \'World\', integers and keywords \'ALL\' only acceptable values","count":{"value":0,"started":"0001-01-01T00:00:00","finished":"0001-01-01T00:00:00","durationSeconds":0.0},"datasetTimer":null},"dataset":[]}'

# %% [markdown]
# ### [API portal](https://comtrade.un.org/data/dev/portal#subscription)

# %%
print(un_data.status_code)
# Out:
# 200

# %%
un_data.json()
# Out:
# {'validation': {'status': {'name': 'Invalid parameter',
#    'value': 5004,
#    'category': 0,
#    'description': 'the selected query does not accept the passed option.',
#    'helpUrl': 'For more reference visit http://comtrade.un.org/data/dev/portal/'},
#   'message': "Invalid argument format: 'World', integers and keywords 'ALL' only acceptable values",
#   'count': {'value': 0,
#    'started': '0001-01-01T00:00:00',
#    'finished': '0001-01-01T00:00:00',
#    'durationSeconds': 0.0},
#   'datasetTimer': None},
#  'dataset': []}

# %%
read_file = pd.read_excel (r'.\data\raw\UN Comtrade Country List.xls')
read_file.to_csv(r'.\data\raw\UN Comtrade Country List.csv', index = None, header=True)

# %%
read_file
# Out:
#      ctyCode       cty Name English            cty Fullname English  \
# 0          0                  World                           World
# 1          4            Afghanistan                     Afghanistan
# 2          8                Albania                         Albania
# 3         10             Antarctica                      Antarctica
# 4         12                Algeria                         Algeria
# ..       ...                    ...                             ...
# 288      887                  Yemen                           Yemen
# 289      890         Fmr Yugoslavia               Former Yugoslavia
# 290      891  Serbia and Montenegro           Serbia and Montenegro
# 291      894                 Zambia                          Zambia
# 292      899             Areas, nes  Areas, not elsewhere specified
#
#           Cty Abbreviation                         Cty Comments  \
# 0                    World                                  NaN
# ...

# %%
country_list = pd.read_csv(r'.\data\raw\UN Comtrade Country List.csv')
country_list
# Out:
#      ctyCode       cty Name English            cty Fullname English  \
# 0          0                  World                           World
# 1          4            Afghanistan                     Afghanistan
# 2          8                Albania                         Albania
# 3         10             Antarctica                      Antarctica
# 4         12                Algeria                         Algeria
# ..       ...                    ...                             ...
# 288      887                  Yemen                           Yemen
# 289      890         Fmr Yugoslavia               Former Yugoslavia
# 290      891  Serbia and Montenegro           Serbia and Montenegro
# 291      894                 Zambia                          Zambia
# 292      899             Areas, nes  Areas, not elsewhere specified
#
#           Cty Abbreviation                         Cty Comments  \
# 0                    World                                  NaN
# ...

# %%
print(country_list['ISO3-digit Alpha'])
print(country_list.ctyCode)
# Out:
# 0      WLD
# 1      AFG
# 2      ALB
# 3      ATA
# 4      DZA
#       ...
# 288    YEM
# 289    YUG
# 290    SCG
# 291    ZMB
# 292    NaN
# Name: ISO3-digit Alpha, Length: 293, dtype: object
# 0        0
# 1        4
# 2        8
# 3       10
# 4       12
#       ...
# 288    887
# 289    890
# 290    891
# 291    894
# 292    899
# Name: ctyCode, Length: 293, dtype: int64

# %%
import numpy as np
import pandas as pd
# cargo clase y funciones creadas por Eoin O'Keeffe para descargar datos de UNComtrade
import getTradeDataFromComtrade

# %%
comapi = getTradeDataFromComtrade.ComtradeApi()
# prueba con un pais y un producto
df = comapi.getComtradeData(comcodes=["1206"], reporter=['32'], partner=['0'], years=[2019], freq='A', rg=['1'], fmt='json', rowmax=50000)
# Out:
# C:\Programas\miniconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'comtrade.un.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
df.cmdCode
# Out:
# 0    1206
# Name: cmdCode, dtype: object

# %%
df
# Out:
#   pfCode    yr  period periodDesc  aggrLevel  IsLeaf  rgCode  rgDesc  rtCode  \
# 0     H5  2019    2019       2019          4       0       1  Import      32
#
#      rtTitle  ... qtAltCode  qtAltDesc TradeQuantity AltQuantity NetWeight  \
# 0  Argentina  ...      None                   572579        None    572579
#
#   GrossWeight TradeValue CIFValue FOBValue estCode
# 0        None    2077726     None     None       0
#
# [1 rows x 35 columns]

# %%
## pruebo con 2 países y 2 productos
df2 = comapi.getComtradeData(comcodes=['1206',"1005"], reporter=['32','28'], partner=['0'], years=[2017], freq='A', rg=['1'], fmt='json', rowmax=50000)
# Out:
# C:\Programas\miniconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'comtrade.un.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
df2
# Out:
#   pfCode    yr  period periodDesc  aggrLevel  IsLeaf  rgCode  rgDesc  rtCode  \
# 0     H4  2017    2017       2017          4       0       1  Import      32
# 1     H4  2017    2017       2017          4       0       1  Import      32
# 2     H3  2017    2017       2017          4       0       1  Import      28
# 3     H3  2017    2017       2017          4       0       1  Import      28
#
#                rtTitle  ... qtAltCode  qtAltDesc TradeQuantity AltQuantity  \
# 0            Argentina  ...      None                 11115666        None
# 1            Argentina  ...      None                   360233        None
# 2  Antigua and Barbuda  ...      None                    53189        None
# 3  Antigua and Barbuda  ...      None                     3636        None
#
#   NetWeight GrossWeight TradeValue CIFValue FOBValue estCode
# 0  11115666        None   29400199     None     None       0
# 1    360233        None    2134731     None     None       0
# ...

# %%
# pruebo con un loop para consutlar distintos años
year = ['2017','2018','2019']
appended_data = []
for y in range(0,3):
    data_prod = comapi.getComtradeData(comcodes=['1206', '0409', '1005'], reporter=['32'], partner=['0'], years=[year[y]], freq='A', rg=['1'], fmt='json', rowmax=50000)
    # store DataFrame in list
    appended_data.append(data_prod)
# see pd.concat documentation for more info
appended_data = pd.concat(appended_data)
# Out:
# C:\Programas\miniconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'comtrade.un.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Programas\miniconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'comtrade.un.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Programas\miniconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'comtrade.un.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
# ok funciona
appended_data
# Out:
#   pfCode    yr  period periodDesc  aggrLevel  IsLeaf  rgCode  rgDesc  rtCode  \
# 0     H4  2017    2017       2017          4       0       1  Import      32
# 1     H4  2017    2017       2017          4       0       1  Import      32
# 0     H5  2018    2018       2018          4       0       1  Import      32
# 1     H5  2018    2018       2018          4       0       1  Import      32
# 0     H5  2019    2019       2019          4       0       1  Import      32
# 1     H5  2019    2019       2019          4       0       1  Import      32
#
#      rtTitle  ... qtAltCode  qtAltDesc TradeQuantity AltQuantity NetWeight  \
# 0  Argentina  ...      None                 11115666        None  11115666
# 1  Argentina  ...      None                   360233        None    360233
# 0  Argentina  ...      None                  6741541        None   6741541
# 1  Argentina  ...      None                   219566        None    219566
# ...

# %%
# descargo lista completa de países
country_list = pd.read_csv(r'UN Comtrade Country List.csv')
country_list
# Out:
#      ctyCode       cty Name English            cty Fullname English  \
# 0          0                  World                           World
# 1          4            Afghanistan                     Afghanistan
# 2          8                Albania                         Albania
# 3         10             Antarctica                      Antarctica
# 4         12                Algeria                         Algeria
# ..       ...                    ...                             ...
# 288      887                  Yemen                           Yemen
# 289      890         Fmr Yugoslavia               Former Yugoslavia
# 290      891  Serbia and Montenegro           Serbia and Montenegro
# 291      894                 Zambia                          Zambia
# 292      899             Areas, nes  Areas, not elsewhere specified
#
#           Cty Abbreviation                         Cty Comments  \
# 0                    World                                  NaN
# ...

# %%
# armo lista de países para hacer la consulta en Comtrade
len(country_list.ctyCode)
countries = country_list.ctyCode
print(type(countries.to_list()))
countries_string = [str(x) for x in  countries.to_list()]
print(countries_string)
# Out:
# <class 'list'>
# ...

# %%
# descargo lista completa de bienes
lista_bienes = pd.read_excel(r'UN Comtrade Commodity Classifications.xlsx')
lista_bienes
# Out:
#       Classification   Code  \
# 0                 BE      1
# 1                 BE     11
# 2                 BE    111
# 3                 BE    112
# 4                 BE     12
# ...              ...    ...
# 51755             S4   9710
# 51756             S4  97101
# 51757             S4  97102
# 51758             S4  97103
# 51759             S4  TOTAL
#
#                                              Description Code Parent  Level  \
# 0                                     Food and beverages       TOTAL      1
# 1                            Food and beverages, primary           1      2
# 2       Food and beverages, primary, mainly for industry          11      3
# 3      Food and beverages, primary, mainly for househ...          11      3
# 4                          Food and beverages, processed           1      2
# ...                                                  ...         ...    ...
# 51755  Gold, non-monetary (excluding gold ores and co...         971      4
# ...

# %%
# selecciono codigo de bienes a 4 dígitos del sistema armonizado 
# H1 corresponde a la nomenclatura de 1996 para poder comparar con años posteriores
# idea comparar un promedio de años para los últimos 20 años: 1997-99, 2007-09 y 2017-19 
lista_bienes[lista_bienes['Code'].map(len) == 4].Classification.unique()
# Out:
# array(['H0', 'H1', 'H2', 'H3', 'H4', 'H5', 'S1', 'S2', 'S3', 'S4'],
#       dtype=object)

# %%
# selecciono 4 digitos y H1
bienes_4dig = lista_bienes[(lista_bienes['Code'].map(len) == 4) & (lista_bienes['Classification'] == 'H1')]
bienes_4dig
# Out:
#       Classification  Code                                        Description  \
# 6412              H1  0101             Horses, asses, mules and hinnies; live
# 6416              H1  0102                               Bovine animals; live
# 6419              H1  0103                                        Swine; live
# 6423              H1  0104                              Sheep and goats; live
# 6426              H1  0105  Poultry; live, fowls of the species gallus dom...
# ...              ...   ...                                                ...
# 12872             H1  9703  Sculptures and statuary; original, in any mate...
# 12874             H1  9704  Stamps, postage or revenue; stamp-postmarks, f...
# 12876             H1  9705  Collections and collectors' pieces; of zoologi...
# 12878             H1  9706    Antiques; of an age exceeding one hundred years
# 12881             H1  9999        Commodities not specified according to kind
#
#       Code Parent  Level  isLeaf
# ...

# %%
# armo lista para hacer consulta en comtrade
cod_bs_4dig = bienes_4dig.Code.to_list()
len(cod_bs_4dig)
# Out:
# 1242

# %%
type(cod_bs_4dig)
cod_bs_4dig[1239:]
# Out:
# ['9705', '9706', '9999']

# %%
# pruebo con una consulta para todos los productos con un país y un año
comapi.getComtradeData(comcodes=cod_bs_4dig[1239:], reporter=['32'], partner=['0'], years=['2019'], freq='A', rg=['1'], fmt='json', rowmax=50000)
# Out:
# C:\Programas\miniconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'comtrade.un.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#   pfCode    yr  period periodDesc  aggrLevel  IsLeaf  rgCode  rgDesc  rtCode  \
# 0     H5  2019    2019       2019          4       0       1  Import      32
# 1     H5  2019    2019       2019          4       0       1  Import      32
# 2     H5  2019    2019       2019          4       0       1  Import      32
#
#      rtTitle  ... qtAltCode  qtAltDesc TradeQuantity AltQuantity NetWeight  \
# 0  Argentina  ...      None                        0        None         0
# 1  Argentina  ...      None                     2910        None      2910
# 2  Argentina  ...      None                     3956        None      3956
#
# ...

# %%
# Armo consulta para iterar sobre 3 años
# consulto todos los bienes a 4 dígitos (H1)
# reporter = todos los países
# partner = Mundo
# trade flow = imports 
year = ['2017','2018','2019']
appended_data = []
for y in range(0,3):
        data_prod = comapi.getComtradeData(comcodes=cod_bs_4dig, reporter=countries_string, partner=['0'], years=[year[y]], freq='A', rg=['1'], fmt='json', rowmax=50000)
        # store DataFrame in list
        appended_data.append(data_prod)
        # see pd.concat documentation for more info
appended_data = pd.concat(appended_data)
# Out:
# C:\Programas\miniconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'comtrade.un.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# WARNING:root:No json object to be parsed
# WARNING:root:Trying running the string below in your browser -is there an error?
# WARNING:root:return string: <Response [404]>
# ...

# %%
import requests
url='https://comtrade.un.org/api/get?max=100&type=C&freq=A&px=HS&ps=2019&r=all&p=World&rg=all&cc=9999'
un_data=requests.get(url)
print(un_data.content)
# Out:
# b'{"validation":{"status":{"name":"Invalid parameter","value":5004,"category":0,"description":"the selected query does not accept the passed option.","helpUrl":"For more reference visit http://comtrade.un.org/data/dev/portal/"},"message":"Invalid argument format: \'World\', integers and keywords \'ALL\' only acceptable values","count":{"value":0,"started":"0001-01-01T00:00:00","finished":"0001-01-01T00:00:00","durationSeconds":0.0},"datasetTimer":null},"dataset":[]}'
